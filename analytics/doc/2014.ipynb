# %%
import sys
sys.path.append("C:\\Users\\jernelson\\Development\\jpn-app-dev\\Lib\\site-packages")
import helpers
import redis
from pymongo import Connection
analytics = redis.StrictRedis()
datastore = Connection(port=27018)
print("Total keys in analytics={}\n\tIII Items={}".format(analytics.dbsize(), analytics.get('iii-item')))
print("Top 100 items")
top_ten = []
for r in analytics.zrevrange('item-checkouts', 0, 100, withscores=True):
    item_number = analytics.hget(r[0], 'number')
    marc = datastore.marc.bibliographic.find_one({"fields.945.subfields.y": item_number},
                                                 {"fields.100", "fields.245"})
    authors, title = [], str()
    for field in marc.get('fields'):
        if len(field) > 0:
            tag = field.keys()[0]
            value = ''.join([subfield.get('a','') for subfield in field[tag].get('subfields')])
            if tag.startswith('100'):
                authors.append(value)
            if tag.startswith('245'):
                title = value
    top_ten.append({"title": title, "count": r[1]})
    print(u"\t{} by {} {} Checkouts. Redis key {} datastore ID {}".format(title, 
                                                                       ' '.join(authors), 
                                                                       r[1],
                                                                       r[0],
                                                                       marc.get("_id")))
# Out:
# Total keys in analytics=997255
# 	III Items=865076
# Top 100 items
# 	Monty Python and the Holy Grail by  331.0 Checkouts. Redis key iii-item:99742 datastore ID 52fe874b650b8c1454108f59
# 	LAPTOP 013 - DELL LATITUDE E5400. by DELL. 241.0 Checkouts. Redis key iii-item:758537 datastore ID 530297c1650b8c11646ba46f
# 	Raising Arizona by  225.0 Checkouts. Redis key iii-item:88282 datastore ID 52fe8723650b8c145410625e
# 	The Sting by  215.0 Checkouts. Redis key iii-item:72127 datastore ID 52fe86ec650b8c145410228e
# 	Out of Africa by  203.0 Checkouts. Redis key iii-item:71404 datastore ID 52fe86e9650b8c1454101fb6
# 	Fargo by  199.0 Checkouts. Redis key iii-item:176973 datastore ID 52fe99b8650b8c145412c9c3
# 	Platoon by  196.0 Checkouts. Redis key iii-item:72258 datastore ID 52fe86ec650b8c1454102311
# 	I'm gonna git you sucka by  195.0 Checkouts. Redis key iii-item:83600 datastore ID 52fe8713650b8c1454104f81
# 	Women on the verge of a nervous breakdown by  191.0 Checkouts. Redis key iii-item:84150 datastore ID 52fe8714650b8c14541051a9
# 	Pulp fiction by  189.0 Checkouts. Redis key iii-item:136150 datastore ID 52fe9930650b8c14541279e3
# 	HEADPHONE  by  185.0 Checkouts. Redis key iii-item:319238 datastore ID 52feaaa9650b8c145415878d
# 	Rosencrantz and Guilderstern are dead by  178.0 Checkouts. Redis key iii-item:93417 datastore ID 52fe8736650b8c1454107689
# 	LAPTOP 014 - DELL LATITUDE E5400. by DELL. 174.0 Checkouts. Redis key iii-item:758544 datastore ID 530297c1650b8c11646ba472
# 	One flew over the cuckoo's nest by  174.0 Checkouts. Redis key iii-item:73325 datastore ID 52fe86f0650b8c1454102746
# 	Forrest Gump by  172.0 Checkouts. Redis key iii-item:136148 datastore ID 52fe9930650b8c14541279e2
# 	Welcome to the dollhouse by  169.0 Checkouts. Redis key iii-item:206961 datastore ID 52fe9a38650b8c145413049c
# 	BOOMBOX  by  164.0 Checkouts. Redis key iii-item:680128 datastore ID 52fead96650b8c1454170596
# 	A Room with a view by  162.0 Checkouts. Redis key iii-item:70480 datastore ID 52fe86e6650b8c1454101c15
# 	Raiders of the lost ark by  154.0 Checkouts. Redis key iii-item:72129 datastore ID 52fe86ec650b8c1454102290
# 	The World according to Garp by  153.0 Checkouts. Redis key iii-item:72771 datastore ID 52fe86ee650b8c1454102519
# 	Dead Poets Society by  153.0 Checkouts. Redis key iii-item:406455 datastore ID 52fe9efe650b8c1454147f39
# 	Short cuts by  146.0 Checkouts. Redis key iii-item:375597 datastore ID 52fe9ec8650b8c1454145e86
# 	Sense and sensibility by  146.0 Checkouts. Redis key iii-item:170953 datastore ID 52fe9994650b8c145412bdee
# 	Young Frankenstein by  142.0 Checkouts. Redis key iii-item:72125 datastore ID 52fe86ec650b8c145410228c
# 	Vertigo by  137.0 Checkouts. Redis key iii-item:80943 datastore ID 52fe870a650b8c145410451e
# 	Trainspotting by  137.0 Checkouts. Redis key iii-item:275114 datastore ID 52fe9af3650b8c1454138c27
# 	Sleeper by  136.0 Checkouts. Redis key iii-item:85700 datastore ID 52fe8719650b8c14541057cd
# 	Fight club by  135.0 Checkouts. Redis key iii-item:366281 datastore ID 52feab41650b8c145415dcbc
# 	Catch 22 by  131.0 Checkouts. Redis key iii-item:73644 datastore ID 52fe86f1650b8c1454102888
# 	Zoot suit by  130.0 Checkouts. Redis key iii-item:92195 datastore ID 52fe8730650b8c14541071c1
# 	Raging bull by  130.0 Checkouts. Redis key iii-item:67289 datastore ID 52fe86dc650b8c1454100f8e
# 	The mambo kings by  130.0 Checkouts. Redis key iii-item:138886 datastore ID 52fe9937650b8c1454127f3c
# 	Amores perros by  126.0 Checkouts. Redis key iii-item:385462 datastore ID 52fe9ed7650b8c1454146861
# 	Sopranos.  by  123.0 Checkouts. Redis key iii-item:355506 datastore ID 52fe9e9c650b8c14541443f3
# 	Adaptation by  121.0 Checkouts. Redis key iii-item:355705 datastore ID 52feab23650b8c145415cb5b
# 	Unforgiven by  120.0 Checkouts. Redis key iii-item:192474 datastore ID 52fe9a0e650b8c145412e842
# 	Manhattan by  119.0 Checkouts. Redis key iii-item:73415 datastore ID 52fe86f0650b8c14541027a0
# 	Sophie's choice by  119.0 Checkouts. Redis key iii-item:72719 datastore ID 52fe86ee650b8c14541024e2
# 	Witness by  119.0 Checkouts. Redis key iii-item:71913 datastore ID 52fe86eb650b8c14541021b7
# 	Sid & Nancy by  118.0 Checkouts. Redis key iii-item:67295 datastore ID 52fe86dc650b8c1454100f94
# 	My big fat Greek wedding by  118.0 Checkouts. Redis key iii-item:351147 datastore ID 52feab14650b8c145415c27c
# 	The graduate by  117.0 Checkouts. Redis key iii-item:333831 datastore ID 52feaad8650b8c145415a05c
# 	The Man from Snowy River by  113.0 Checkouts. Redis key iii-item:99745 datastore ID 52fe874b650b8c1454108f5c
# 	New York stories by  112.0 Checkouts. Redis key iii-item:90324 datastore ID 52fe872a650b8c1454106a72
# 	The Big chill by  112.0 Checkouts. Redis key iii-item:72128 datastore ID 52fe86ec650b8c145410228f
# 	The Shawshank redemption by  111.0 Checkouts. Redis key iii-item:302664 datastore ID 52feaa43650b8c1454157062
# 	Glory by  110.0 Checkouts. Redis key iii-item:85752 datastore ID 52fe871a650b8c1454105801
# 	Hable con ella by  109.0 Checkouts. Redis key iii-item:356999 datastore ID 52feab27650b8c145415cdf4
# 	Stand by me by  108.0 Checkouts. Redis key iii-item:64416 datastore ID 52fe86d3650b8c1454100454
# 	Y tu mamá también by  108.0 Checkouts. Redis key iii-item:330915 datastore ID 52feaacc650b8c1454159a76
# 	Party girl by  108.0 Checkouts. Redis key iii-item:216416 datastore ID 52fe9a53650b8c1454131734
# 	Robin Hood by  108.0 Checkouts. Redis key iii-item:154612 datastore ID 52fe9965650b8c1454129def
# 	APPLE - MacBook Pro. by APPLE. 107.0 Checkouts. Redis key iii-item:265563 datastore ID 5302a228650b8c11646f5890
# 	The Handmaid's tale by  106.0 Checkouts. Redis key iii-item:78349 datastore ID 52fe8702650b8c1454103afa
# 	The Last emperor by  106.0 Checkouts. Redis key iii-item:70912 datastore ID 52fe86e8650b8c1454101dc9
# 	Taxi driver by  106.0 Checkouts. Redis key iii-item:305832 datastore ID 52fe9e17650b8c145413ed26
# 	Mississippi burning by  103.0 Checkouts. Redis key iii-item:84333 datastore ID 52fe8715650b8c1454105262
# 	Tootsie by  103.0 Checkouts. Redis key iii-item:72913 datastore ID 52fe86ee650b8c14541025a7
# 	My fair lady by  103.0 Checkouts. Redis key iii-item:72191 datastore ID 52fe86ec650b8c14541022ce
# 	Shakespeare in love by  103.0 Checkouts. Redis key iii-item:314198 datastore ID 52fe9e29650b8c145413f89f
# 	Rashomon by  102.0 Checkouts. Redis key iii-item:72764 datastore ID 52fe86ee650b8c1454102510
# 	Some like it hot by  101.0 Checkouts. Redis key iii-item:63081 datastore ID 52fe86cf650b8c14540fff1d
# 	A clockwork orange by  101.0 Checkouts. Redis key iii-item:360195 datastore ID 52feab35650b8c145415d558
# 	Wonder boys by  100.0 Checkouts. Redis key iii-item:353217 datastore ID 52fe9e95650b8c1454143f44
# 	Minority report by  100.0 Checkouts. Redis key iii-item:337877 datastore ID 52feaae6650b8c145415a85f
# 	The Royal Tenenbaums by  99.0 Checkouts. Redis key iii-item:529412 datastore ID 52feac50650b8c1454167e85
# 	Hedwig and the angry inch by  99.0 Checkouts. Redis key iii-item:306757 datastore ID 52feaa4e650b8c145415761d
# 	Rope by  97.0 Checkouts. Redis key iii-item:87750 datastore ID 52fe8721650b8c1454106041
# 	Slacker by  97.0 Checkouts. Redis key iii-item:135175 datastore ID 52fe992d650b8c14541277f8
# 	Alfred Hitchcock's rear window by  96.0 Checkouts. Redis key iii-item:338190 datastore ID 52fe9e69650b8c1454142105
# 	North by Northwest by  95.0 Checkouts. Redis key iii-item:78365 datastore ID 52fe8702650b8c1454103b0a
# 	Thin blue line by  95.0 Checkouts. Redis key iii-item:58284 datastore ID 52fe86c0650b8c14540fec4d
# 	Pan's labyrinth by  94.0 Checkouts. Redis key iii-item:719279 datastore ID 52feadec650b8c1454173803
# 	Ghost world by  94.0 Checkouts. Redis key iii-item:398753 datastore ID 52fe9ef1650b8c14541476c0
# 	A history of Argentine political thought. by Romero, Jose? Luis, 93.0 Checkouts. Redis key iii-item:56497 datastore ID 52fe86b8650b8c14540fe54e
# 	Roman holiday by  92.0 Checkouts. Redis key iii-item:70755 datastore ID 52fe86e7650b8c1454101d2b
# 	Jackie Brown by  92.0 Checkouts. Redis key iii-item:333814 datastore ID 52feaad8650b8c145415a054
# 	Shadowlands by  92.0 Checkouts. Redis key iii-item:122181 datastore ID 52fe9909650b8c1454125e9f
# 	Abre los ojos by  91.0 Checkouts. Redis key iii-item:398088 datastore ID 52fe9ef0650b8c14541475d2
# 	Strictly ballroom by  91.0 Checkouts. Redis key iii-item:305705 datastore ID 52fe9e17650b8c145413ecfc
# 	Never cry wolf by  90.0 Checkouts. Redis key iii-item:77871 datastore ID 52fe8701650b8c145410391a
# 	She's gotta have it by  90.0 Checkouts. Redis key iii-item:72925 datastore ID 52fe86ee650b8c14541025b3
# 	Rebel without a cause by  90.0 Checkouts. Redis key iii-item:71667 datastore ID 52fe86ea650b8c14541020c0
# 	Blue velvet by  90.0 Checkouts. Redis key iii-item:330255 datastore ID 52feaaca650b8c1454159925
# 	The secret of Roan Inish by  90.0 Checkouts. Redis key iii-item:172659 datastore ID 52fe9999650b8c145412c146
# 	Vampire hunter D by  89.0 Checkouts. Redis key iii-item:374772 datastore ID 52fe9ec6650b8c1454145d91
# 	Rumble in the Bronx by  89.0 Checkouts. Redis key iii-item:149608 datastore ID 52fe9957650b8c1454129431
# 	Powwow highway by  88.0 Checkouts. Redis key iii-item:63082 datastore ID 52fe86cf650b8c14540fff1e
# 	To die for by  88.0 Checkouts. Redis key iii-item:273973 datastore ID 52fe9af0650b8c14541389ef
# 	Caro diario by  88.0 Checkouts. Redis key iii-item:128246 datastore ID 52fe991a650b8c1454126a78
# 	Dirty pretty things by  87.0 Checkouts. Redis key iii-item:487586 datastore ID 52feac0e650b8c14541655a9
# 	Smoke signals by  86.0 Checkouts. Redis key iii-item:768420 datastore ID 52feae73650b8c14541784d1
# 	Wings of desire by  86.0 Checkouts. Redis key iii-item:68541 datastore ID 52fe86e0650b8c1454101476
# 	Crimes and misdemeanors by  86.0 Checkouts. Redis key iii-item:366321 datastore ID 52fe9eb7650b8c14541454a0
# 	Casablanca by  86.0 Checkouts. Redis key iii-item:356381 datastore ID 52feab25650b8c145415ccae
# 	Saving Private Ryan by  86.0 Checkouts. Redis key iii-item:346283 datastore ID 52feab03650b8c145415b928
# 	Easy rider by  86.0 Checkouts. Redis key iii-item:312647 datastore ID 52feaa66650b8c1454157e33
# 	I shot Andy Warhol by  86.0 Checkouts. Redis key iii-item:273494 datastore ID 52fe9aee650b8c14541388fd
# 	Kolya by  86.0 Checkouts. Redis key iii-item:203911 datastore ID 52fe9a2f650b8c145412fe9f
# 	Apocalypse now by  85.0 Checkouts. Redis key iii-item:381548 datastore ID 52fe9ed1650b8c145414646d
# 	Alfred Hitchcock's North by northwest by  85.0 Checkouts. Redis key iii-item:306190 datastore ID 52fe9e18650b8c145413eda5

# %%
from bson import ObjectId
datastore.marc.bibliographic.find_one({"_id": ObjectId('530297c1650b8c11646ba46f')})
# Out:
# {u'_id': ObjectId('530297c1650b8c11646ba46f'),
#  u'fields': [{u'008': u'                                   eng  '},
#   {u'100': {u'ind1': u' ', u'ind2': u' ', u'subfields': [{u'a': u'DELL.'}]}},
#   {u'245': {u'ind1': u' ',
#     u'ind2': u'0',
#     u'subfields': [{u'a': u'LAPTOP 013 - DELL LATITUDE E5400.'}]}},
#   {u'500': {u'ind1': u' ',
#     u'ind2': u' ',
#     u'subfields': [{u'a': u'Upon return check for the following 6 items: #1 Carrying Bag, #2 Dell Laptop s/n 4M8DLK1, #3 Ethernet Cable, #4 Mouse, #5 Power Cable, #6 Instruction Notebook.'}]}},
#   {u'902': {u'ind1': u' ', u'ind2': u' ', u'subfields': [{u'a': u'140113'}]}},
#   {u'907': {u'ind1': u' ',
#     u'ind2': u' ',
#     u'subfields': [{u'a': u'.b1951752x'}]}},
#   {u'945': {u'ind1': u' ',
#     u'ind2': u' ',
#     u'subfields': [{u'a': u'LAPTOP 013'},
#      {u'g': u'1'},
#      {u'i': u'33027005880467'},
#      {u'j': u'0'},
#      {u'l': u'tzlap'},
#      {u'm': u'Upon return check for the following 5 items: #1 Carrying Bag, #2 Dell Laptop s/n 4M8DLK1, #3 Mouse, #4 Power Cable, #5 Instruction Notebook.'},
#      {u'h': u'0'},
#      {u'o': u'c'},
#      {u'p': u'$0.00'},
#      {u'q': u' '},
#      {u'r': u'-'},
#      {u's': u'-'},
#      {u't': u'39'},
#      {u'u': u'234'},
#      {u'v': u'0'},
#      {u'w': u'1'},
#      {u'x': u'113'},
#      {u'y': u'.i19671556'},
#      {u'z': u'090903'}]}},
#   {u'994': {u'ind1': u' ', u'ind2': u' ', u'subfields': [{u'a': u'tzlap'}]}},
#   {u'999': {u'ind1': u' ',
#     u'ind2': u' ',
#     u'subfields': [{u'b': u'0'},
#      {u'c': u'090903'},
#      {u'd': u'm'},
#      {u'e': u'-'},
#      {u'f': u'a'},
#      {u'g': u'0'}]}}],
#  u'leader': u'00697nam  2200133 a 4500',
#  u'recordInfo': {u'languageOfCataloging': u'http://id.loc.gov/vocabulary/iso639-1/en',
#   u'recordContentSource': u'CoCCC',
#   u'recordCreationDate': u'2014-02-17T23:14:09.582000',
#   u'recordOrigin': u'From Colorado College MARC21 records'}}

# %%
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(1)
last_year = datetime.datetime.utcnow().year
years = [year for year in xrange(last_year-15, last_year)]
checkouts = [analytics.bitcount('{}:checkouts'.format(year)) for year in years]
plt.plot(years, checkouts, 'ro-')
plt.ylabel('Number of checkouts')
plt.xlabel('Year')
plt.title("Patron Checkouts per Year")
plt.show()
for i,year in enumerate(years):
    print("{}: {}".format(year, checkouts[i]))
# Out:
# 1999: 47
# 2000: 141
# 2001: 2857
# 2002: 4153
# 2003: 4715
# 2004: 5520
# 2005: 6181
# 2006: 7008
# 2007: 8311
# 2008: 9312
# 2009: 10196
# 2010: 11842
# 2011: 13133
# 2012: 14372
# 2013: 16027

# %%
#print([x.get('count') for x in top_ten])
plt.figure(2)
plt.title("Most Checked Out Items")
plt.subplot(3, 1, 1)
plt.plot([x.get('count') for x in top_ten])
plt.ylabel("Top 10")
plt.xlabel("Number of checkouts")
plt.subplot(3, 1, 2)
plt.plot([x[1] for x in analytics.zrevrange('item-checkouts', 0, 100, withscores=True)])
plt.ylabel("Top 100")
plt.xlabel("Number of checkouts")
plt.subplot(3, 1, 3)
plt.plot([x[1] for x in analytics.zrevrange('item-checkouts', 0, 1000, withscores=True)])
plt.ylabel("Top 1,000")
plt.xlabel("Number of checkouts")
#plt.xticks([int(x.get('count')) for x in top_ten])
plt.show()
plt.title("Checkouts follow a long-tail distribution")
plt.subplot(3, 1, 1)
plt.plot([x[1] for x in analytics.zrevrange('item-checkouts', 0, 10000, withscores=True)])
plt.ylabel("Top 10,000")
plt.xlabel("Number of checkouts")
plt.subplot(3, 1, 2)
plt.plot([x[1] for x in analytics.zrevrange('item-checkouts', 0, 100000, withscores=True)])
plt.ylabel("Top 100,000")
plt.xlabel("Number of checkouts")
plt.show()

# %%
from collections import OrderedDict
months = OrderedDict({0:'January', 1:'February', 2:'March'})
plt.figure(3)
plt.title("Circulation Activity January-March 2014")
circ_stats_q1 = [analytics.bitcount('2014-0{}:checkouts'.format(month+1)) for month in months.keys()]
plt.plot(circ_stats_q1)
plt.xticks(months.keys(), months.values())
plt.xlabel("Months")
plt.ylabel("Number of checkouts")
plt.show()

# %%
import helpers

# January status
print("Total checkouts for January 2014 is {}".format(analytics.bitcount("2014-01:checkouts")))
jan_stats = helpers.get_month_stats('checkouts', 2014, 1, analytics)
plt.plot([x[1] for x in jan_stats])
plt.title("Checkouts for January 2014")
plt.xlabel("Day of the week")
plt.ylabel("Number of checkouts")
plt.show()
print("Total checkouts for February 2014 is {}".format(analytics.bitcount("2014-02:checkouts")))
feb_stats = helpers.get_month_stats('checkouts', 2014, 2, analytics)
plt.plot([x[1] for x in feb_stats])
plt.title("Checkouts for February 2014")
plt.xlabel("Day of the week")
plt.ylabel("Number of checkouts")

plt.show()
print("Total checkouts for March 2014 is {}".format(analytics.bitcount("2014-03:checkouts")))
mar_stats = helpers.get_month_stats('checkouts', 2014, 3, analytics)
plt.plot([x[1] for x in mar_stats])
plt.title("Checkouts for March 2014")
plt.xlabel("Day of the week")
plt.ylabel("Number of checkouts")
plt.show()
first_quarter = [x[1] for x in jan_stats]
first_quarter.extend([x[1] for x in feb_stats])
first_quarter.extend([x[1] for x in mar_stats])
plt.title("Daily Checkouts Jan-Mar 2014")
plt.plot(first_quarter)
plt.show()
# Out:
# Total checkouts for January 2014 is 1546
# Total checkouts for February 2014 is 2110
# Total checkouts for March 2014 is 1608

# %%
print("Total checkouts for April 2014 is {}".format(analytics.bitcount("2014-04:checkouts")))
apr_stats = helpers.get_month_stats('checkouts', 2014, 4, analytics)
second_quarter = [x[1] for x in apr_stats]
plt.plot([x[1] for x in apr_stats])
plt.title("Checkouts for April 2014")
plt.xlabel("Day of the week")
plt.ylabel("Number of checkouts")
plt.show()
# Out:
# Total checkouts for April 2014 is 1838

# %%
print("Total checkouts for May 2014 is {}".format(analytics.bitcount("2014-05:checkouts")))
may_stats = helpers.get_month_stats('checkouts', 2014, 5, analytics)
second_quarter.extend([x[1] for x in may_stats])
plt.plot([x[1] for x in may_stats])
plt.title("Checkouts for May 2014")
plt.xlabel("Day of the week")
plt.ylabel("Number of checkouts")
plt.show()
# Out:
# Total checkouts for May 2014 is 696

# %%
year_stats = first_quarter + second_quarter
plt.title("Total checkouts for 2014")
plt.plot(year_stats)
plt.xlabel("Day of the year")
plt.ylabel("Number of checkouts")
plt.show()

# %%
def print_month(stats):
    for r in stats:
        print("{} count={}".format(r[0].strftime("%B %d"), r[1]))
